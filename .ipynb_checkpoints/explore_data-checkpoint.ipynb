# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
from sklearn import decomposition
from sklearn import preprocessing
pd.set_option('display.max_columns', None)

# %%
data = pd.read_table('data/playlist_summary_external.txt')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403366 entries, 0 to 403365
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   playlist_uri             403366 non-null  object
#  1   owner                    403366 non-null  object
#  2   streams                  403366 non-null  int64
#  3   stream30s                403366 non-null  int64
#  4   dau                      403366 non-null  int64
#  5   wau                      403366 non-null  int64
#  6   mau                      403366 non-null  int64
#  7   mau_previous_month       403366 non-null  int64
#  8   mau_both_months          403366 non-null  int64
#  9   users                    403366 non-null  int64
#  10  skippers                 403366 non-null  int64
#  11  owner_country            403366 non-null  object
#  12  n_tracks                 403366 non-null  int64
#  13  n_local_tracks           403366 non-null  int64
#  14  n_artists                403366 non-null  int64
#  15  n_albums                 403366 non-null  int64
#  16  monthly_stream30s        403366 non-null  int64
#  17  monthly_owner_stream30s  403366 non-null  int64
#  18  tokens                   403366 non-null  object
#  19  genre_1                  403366 non-null  object
#  20  genre_2                  403366 non-null  object
#  21  genre_3                  403366 non-null  object
#  22  mood_1                   403366 non-null  object
#  23  mood_2                   403366 non-null  object
#  24  mood_3                   403366 non-null  object
# dtypes: int64(15), object(10)
# memory usage: 76.9+ MB

# %%
data.describe()
# Out:
#             streams     stream30s            dau            wau           mau  \
# count  4.033660e+05  4.033660e+05  403366.000000  403366.000000  4.033660e+05
# mean   7.101375e+01  4.283333e+01       4.418265      21.784446  6.614290e+01
# std    6.492014e+03  3.772412e+03     358.855685    1614.650805  4.732580e+03
# min    0.000000e+00  0.000000e+00       0.000000       0.000000  2.000000e+00
# 25%    0.000000e+00  0.000000e+00       0.000000       1.000000  2.000000e+00
# 50%    1.000000e+00  0.000000e+00       0.000000       1.000000  2.000000e+00
# 75%    8.000000e+00  5.000000e+00       1.000000       2.000000  4.000000e+00
# max    2.629715e+06  1.513237e+06  152929.000000  669966.000000  1.944150e+06
#
#        mau_previous_month  mau_both_months         users       skippers  \
# count        4.033660e+05    403366.000000  4.033660e+05  403366.000000
# mean         5.819009e+01        12.937065  1.493085e+02       2.827749
# std          3.827248e+03      1240.912979  9.247484e+03     205.059728
# min          0.000000e+00         0.000000  2.000000e+00       0.000000
# 25%          1.000000e+00         1.000000  2.000000e+00       0.000000
# 50%          2.000000e+00         1.000000  3.000000e+00       0.000000
# 75%          3.000000e+00         2.000000  7.000000e+00       0.000000
# max          1.478684e+06    578391.000000  3.455406e+06   86162.000000
#
#             n_tracks  n_local_tracks      n_artists       n_albums  \
# count  403366.000000   403366.000000  403366.000000  403366.000000
# mean      201.483432        3.084035      83.852050      88.224250
# std       584.077765       40.330266     128.152488     133.193118
# min         1.000000        0.000000       1.000000       1.000000
# 25%        38.000000        0.000000      18.000000      19.000000
# 50%        84.000000        0.000000      46.000000      48.000000
# 75%       192.000000        0.000000     100.000000     106.000000
# max     79984.000000     9117.000000    5226.000000    6397.000000
#
#        monthly_stream30s  monthly_owner_stream30s
# count       4.033660e+05            403366.000000
# mean        1.260489e+03                93.556621
# std         1.062463e+05               226.250189
# min         2.000000e+00                 0.000000
# 25%         3.100000e+01                 6.000000
# 50%         7.900000e+01                30.000000
# 75%         1.930000e+02                96.000000
# max         4.249733e+07             25904.000000

# %%
data.nunique()
# Out:
# playlist_uri               403366
# owner                      314899
# streams                      1639
# stream30s                    1329
# dau                           566
# wau                          1019
# mau                          1597
# mau_previous_month           1552
# mau_both_months               765
# users                        2293
# skippers                      522
# owner_country                   1
# n_tracks                     4134
# n_local_tracks                576
# n_artists                    1560
# n_albums                     1621
# monthly_stream30s            6094
# monthly_owner_stream30s      2418
# tokens                     192107
# genre_1                        26
# genre_2                        26
# genre_3                        26
# mood_1                         27
# mood_2                         27
# mood_3                         27
# dtype: int64

# %% [markdown]
# Quick summary of data:  There are no missing values for any of the columns.  Each row is uniquely indexed by playlist_uri.  There are 26 distinct values of the genre variables and 27 distinct values of the mood variables.  There is only one distinct value of owner_country, so we will drop it here.  We should then mention that this analysis only applies to US-created playlists and may or may not generalize to other country's playlists.
#
# Of the 403,366 unique playlists, there are 314,899 distinct playlists and thus most owners in this dataset only have one playlist included.  Let's explore the distribution of the number of playlists each owner has.

# %%
data = data.drop(columns = 'owner_country')

# %%
data.tokens.head(30)
# Out:
# 0     ["ambient", "music", "therapy", "binaural", "b...
# 1                                    ["good", "living"]
# 2                                      ["norte\u00f1a"]
# 3                                                    []
# 4                                   ["cheesy", "pants"]
# 5                                      ["aids", "walk"]
# 6                                            ["classy"]
# 7                                    ["iranian", "rap"]
# 8                                               ["fly"]
# 9                                  ["reading", "music"]
# 10                                    ["mac", "miller"]
# 11                                                   []
# 12                                              ["rap"]
# 13                                                   []
# 14                                    ["sunny", "daze"]
# 15                                       ["croatiaaaa"]
# 16                                 ["gangsta", "party"]
# 17                             ["chiraq", "drillinois"]
# 18                                                   []
# 19                               ["jaheim", "anything"]
# 20                             ["metalcore", "forever"]
# 21                                      ["cafe", "mix"]
# 22    ["music", "walker", "added", "without", "knowi...
# 23                          ["party", "party", "party"]
# 24                                          ["freedom"]
# 25         ["tommy", "lee", "sparta", "sparta", "boss"]
# 26                                           ["summer"]
# 27                                   ["salif", "keita"]
# 28                                           ["mellow"]
# 29                                ["new", "troubadors"]
# Name: tokens, dtype: object

# %%
data.tokens[0]
# Out:
# '["ambient", "music", "therapy", "binaural", "beats", "ambient", "clear", "binaural", "beats"]'

# %%
owner_playlist_counts = (data.
                        groupby('owner').
                        size().
                        reset_index().
                        rename(columns = {0: 'n_playlists'}).
                        query('n_playlists > 1').
                        sort_values('n_playlists', ascending = False)
                        )

# %% [markdown]
# Of the 314,899 unique playlist owners, 261,040 (83%) have exactly one playlist in the data.  There are 399 playlists in which the owner is 'spotify'.  The most playlists by an individual user is 48.  The individual with the 30th most playlists had 21 playlists.

# %%
owner_playlist_counts.head(31)
# Out:
#                                    owner  n_playlists
# 314898                           spotify          399
# 129897  6987037f34b5cee787a1a5e8de9b2689           48
# 203611  a5add6d0d5fbebb01abb2fbe7e47208d           47
# 301721  f54f32d1c706754a70f8392aa1dbad46           44
# 91405   4a03268bef1505a49f8b3eced879f311           43
# 29547   17d6159195b25d619e0eff98f809c90e           40
# 196624  9ff1b837bb1262d44f2194549748385a           40
# 5464    0467e18af314d5c84e3e92f196fb05b9           40
# 47656   2682cc9acee40aa2d9098555fd0f2671           37
# 300043  f3ef29545d1de52e8c1c0062378826e0           34
# 249742  cb305f632c793f009882083e9e75f5b0           33
# 283022  e60d19313a8df36c7e6cf59e259e0d66           31
# 157328  7fc3f5ee009667ada46d513f4785cdc9           30
# 154120  7d31cccb89f1cfd373b6e30988887fc4           29
# 155021  7de407b890bb04b38b76c75e0a3d9b78           27
# 85050   44cbe53c359a780201e3f9ef68b3bc99           26
# 79740   407248c8aa74fff2efc940ab7ed8dfc2           26
# 96592   4e2f07a1453cb9026e3534c3567eb43b           25
# 287032  e95065e8b4fc15c408e92240207053c2           25
# 288155  ea39e2be80d7a119b06e89b1ce074caf           24
# 108248  57b332ccfe3cfae076e9a05a8d2bcc1e           24
# 97218   4eabef0feb9fde66d74a47acf736bd8b           24
# 74613   3c66e3a502edc2a6c2815e229916a4ad           23
# 22065   11ca2afc5521476b8728bf459f868673           23
# 198593  a18725cb7ba9680ece8c7a7291012433           23
# 213350  ad92df835fd811b7249f7c217ffa6b28           22
# 214009  ae21a247133f4e0fe74aeb0b085eb62c           22
# 41421   2186318d6b8037de9c80928e91d0cf3c           22
# 197557  a0b2935cfc0539849dfe6481af161657           22
# 141596  72e0a8e7efa7616ab78b0813a3ee07eb           22
# 143290  743e1240ddb3351c7a602c415720c8f2           21

# %%
owner_playlist_counts.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Let's now try to get an understanding of some of the metrics that could conceivably define a successful playlist.
#
# Classification of Variables:
#
# ID variables:
# 1. playlist_uri -- The key or index of the playlist, each row has unique value of this
# 2.  owner -- playlist owner, most but not all owners only have one playlist
#
# Thoughts on what could constitute success:
# 1. stream30s - Important: this variable only relates to number of streams TODAY
# 2. dau - Number of users with a 30 SECOND stream TODAY
# 3. wau - Number of users with a 30 SECOND stream in the past WEEK
# 4. mau - Number of users with a 30 SECOND stream in past MONTH
# 5. mau_previous_month - Number of users with a 30 SECOND stream in month PRIOR to given month
# 6. mau_both_months - Number of users that were active THIS month and PRIOR month
# 7. users - Number of users with at least one stream of any time duration (including skips) in past MONTH
# 8. monthly_stream30s - Number of streams over 30 seconds this month
# 9. streams - Number of streams from playlist today (Presumably could be any length)
# 10.  monthly_owner_stream30s - number of streams over 30 seconds by PLAYLIST OWNER this month
#
# WEIRD/USELESS VARIABLES:
# 1. skippers - This could be inverse coded as a way of measuring playlist success, however THIS IS A CONFUSING VARIABLE. Number of users who skipped more than 90% of their total Spotify streams today and also used this playlist.  Important note: the way this definition reads, a playlist could be 'punished' for simply having users who skip a lot.  It could be that these skippers are not actually skipping the songs in the given playlist.
# 2.  tokens -- could be a useful variable, but will be hard to parse.
# 3. owner_country - could have been interesting, but dataset is only composed of US playlist owners.
#
# PREDICTORS:
# 1. n_tracks - number of tracks in playlist
# 2. n_local_tracks - number of tracks that are new from yesterday to today
# 3. n_artists - number of unique artists in playlist
# 4. n_albums - number of unique albums in playlist
# 5-7: genre_1, genre_2, genre_3: genre by weight of playlist tracks, from Gracenote metadata
# 8_10: mood_1, mood_2, mood_3: mood by weight of playlist tracks, from Gracenote metadata

# %%
outcomes = (data.
           set_index('playlist_uri').
           loc[:, ['streams', 'stream30s', 'dau', 'wau', 'mau', 'mau_previous_month', 'mau_both_months', 'users',
                  'monthly_stream30s', 'monthly_owner_stream30s']])

# %%
outcomes.head()
# Out:
#                                                     streams  stream30s  dau  \
# playlist_uri
# spotify:user:36069af6af076ccd9e597184a67b68c9:p...       27         27    1
# spotify:user:d1144a65b1c31c5f9f56b94f831124d5:p...        0          0    0
# spotify:user:6b7fbed9edd6418ddd3b555bba441536:p...        4          2    1
# spotify:user:580b98725077a94c3c8d01d07390426b:p...       12         12    1
# spotify:user:1305d39070c95d161cc502e15014897d:p...       20          4    1
#
#                                                     wau  mau  \
# playlist_uri
# spotify:user:36069af6af076ccd9e597184a67b68c9:p...    1    3
# spotify:user:d1144a65b1c31c5f9f56b94f831124d5:p...    1    2
# spotify:user:6b7fbed9edd6418ddd3b555bba441536:p...    1    7
# spotify:user:580b98725077a94c3c8d01d07390426b:p...    1    4
# spotify:user:1305d39070c95d161cc502e15014897d:p...    1    2
#
#                                                     mau_previous_month  \
# playlist_uri
# spotify:user:36069af6af076ccd9e597184a67b68c9:p...                   3
# spotify:user:d1144a65b1c31c5f9f56b94f831124d5:p...                   1
# spotify:user:6b7fbed9edd6418ddd3b555bba441536:p...                   5
# spotify:user:580b98725077a94c3c8d01d07390426b:p...                   6
# spotify:user:1305d39070c95d161cc502e15014897d:p...                   1
#
#                                                     mau_both_months  users  \
# playlist_uri
# spotify:user:36069af6af076ccd9e597184a67b68c9:p...                0      8
# spotify:user:d1144a65b1c31c5f9f56b94f831124d5:p...                1      3
# spotify:user:6b7fbed9edd6418ddd3b555bba441536:p...                0     15
# spotify:user:580b98725077a94c3c8d01d07390426b:p...                1     10
# spotify:user:1305d39070c95d161cc502e15014897d:p...                1      2
#
#                                                     monthly_stream30s  \
# playlist_uri
# spotify:user:36069af6af076ccd9e597184a67b68c9:p...                 30
# spotify:user:d1144a65b1c31c5f9f56b94f831124d5:p...                112
# spotify:user:6b7fbed9edd6418ddd3b555bba441536:p...                 63
# spotify:user:580b98725077a94c3c8d01d07390426b:p...                154
# spotify:user:1305d39070c95d161cc502e15014897d:p...                230
#
#                                                     monthly_owner_stream30s
# playlist_uri
# spotify:user:36069af6af076ccd9e597184a67b68c9:p...                       27
# spotify:user:d1144a65b1c31c5f9f56b94f831124d5:p...                       94
# spotify:user:6b7fbed9edd6418ddd3b555bba441536:p...                        0
# spotify:user:580b98725077a94c3c8d01d07390426b:p...                      108
# spotify:user:1305d39070c95d161cc502e15014897d:p...                        0

# %% [markdown]
# It is interesting to note here that there appears to be very high correlation between each of the outcome variables that I have considered as good outcome variables except for the monthly_owner_stream_30s, which is the number of streams over 30 seconds by the playlist owner this month.  This very weak correlation for monthly_owner_stream30s suggests to me that it likely it should not be considered a good measure of a successful playlist.

# %%
outcomes.corr()
# Out:
#                           streams  stream30s       dau       wau       mau  \
# streams                  1.000000   0.994380  0.988381  0.967860  0.958000
# stream30s                0.994380   1.000000  0.985062  0.968307  0.957810
# dau                      0.988381   0.985062  1.000000  0.986290  0.981306
# wau                      0.967860   0.968307  0.986290  1.000000  0.995568
# mau                      0.958000   0.957810  0.981306  0.995568  1.000000
# mau_previous_month       0.905523   0.908967  0.938572  0.957752  0.969613
# mau_both_months          0.957998   0.956223  0.975665  0.974101  0.969983
# users                    0.911023   0.912391  0.946317  0.970788  0.983961
# monthly_stream30s        0.984383   0.992060  0.980044  0.978300  0.970658
# monthly_owner_stream30s -0.001338  -0.000767 -0.003330 -0.004150 -0.004432
#
#                          mau_previous_month  mau_both_months     users  \
# streams                            0.905523         0.957998  0.911023
# stream30s                          0.908967         0.956223  0.912391
# dau                                0.938572         0.975665  0.946317
# wau                                0.957752         0.974101  0.970788
# mau                                0.969613         0.969983  0.983961
# mau_previous_month                 1.000000         0.954992  0.990228
# mau_both_months                    0.954992         1.000000  0.942426
# users                              0.990228         0.942426  1.000000
# monthly_stream30s                  0.931162         0.971727  0.931219
# monthly_owner_stream30s           -0.004802        -0.003219 -0.005115
#
#                          monthly_stream30s  monthly_owner_stream30s
# streams                           0.984383                -0.001338
# stream30s                         0.992060                -0.000767
# dau                               0.980044                -0.003330
# wau                               0.978300                -0.004150
# mau                               0.970658                -0.004432
# mau_previous_month                0.931162                -0.004802
# mau_both_months                   0.971727                -0.003219
# users                             0.931219                -0.005115
# monthly_stream30s                 1.000000                -0.000519
# monthly_owner_stream30s          -0.000519                 1.000000

# %%
outcomes = outcomes.drop(columns = 'monthly_owner_stream30s')

# %%
outcomes.corr()
# Out:
#                      streams  stream30s       dau       wau       mau  \
# streams             1.000000   0.994380  0.988381  0.967860  0.958000
# stream30s           0.994380   1.000000  0.985062  0.968307  0.957810
# dau                 0.988381   0.985062  1.000000  0.986290  0.981306
# wau                 0.967860   0.968307  0.986290  1.000000  0.995568
# mau                 0.958000   0.957810  0.981306  0.995568  1.000000
# mau_previous_month  0.905523   0.908967  0.938572  0.957752  0.969613
# mau_both_months     0.957998   0.956223  0.975665  0.974101  0.969983
# users               0.911023   0.912391  0.946317  0.970788  0.983961
# monthly_stream30s   0.984383   0.992060  0.980044  0.978300  0.970658
#
#                     mau_previous_month  mau_both_months     users  \
# streams                       0.905523         0.957998  0.911023
# stream30s                     0.908967         0.956223  0.912391
# dau                           0.938572         0.975665  0.946317
# wau                           0.957752         0.974101  0.970788
# mau                           0.969613         0.969983  0.983961
# mau_previous_month            1.000000         0.954992  0.990228
# mau_both_months               0.954992         1.000000  0.942426
# users                         0.990228         0.942426  1.000000
# monthly_stream30s             0.931162         0.971727  0.931219
#
#                     monthly_stream30s
# streams                      0.984383
# stream30s                    0.992060
# dau                          0.980044
# wau                          0.978300
# mau                          0.970658
# mau_previous_month           0.931162
# mau_both_months              0.971727
# users                        0.931219
# monthly_stream30s            1.000000

# %% [markdown]
# It is interesting to note that the good outcome variables all have pairwise correlations of 0.90 or greater, thus signifying that there is considerable agreement amongst these variables.
# Idea: we may eventually want to create some type of PCA of these variables, where we take the first few PCA components and use those as outcome variables.

# %%
outcomes_scaled = preprocessing.scale(outcomes)
#pca = decomposition.PCA(n_components = 'mle')
pca = decomposition.PCA(n_components = 1)
pca.fit(outcomes_scaled)
outcomes_pca = pca.transform(outcomes_scaled)

# %%
outcomes_scaled_df = pd.DataFrame(outcomes_scaled)

# %% [markdown]
# There appear to be a couple playlists that are major outliers in terms of how good they look in terms of the outcomes.  They have id 163726 and 152032.  They are off the charts good, being 250-400 standard deviations above the mean of each outcome.

# %%
outcomes_scaled_df.sort_values(0, ascending = False).head()
# Out:
#                  0           1           2           3           4  \
# 163726  405.058792  401.121606  339.971576  318.710307  307.027583
# 152032  389.248578  387.360368  426.145600  414.916367  410.787813
# 216752  113.248512   92.341075  121.200910  136.125710  145.572538
# 23223   104.492050   98.067657   92.584914   68.790325   51.053579
# 309410   89.224658   70.398059   78.857931   74.135140   71.719499
#
#                  5           6           7           8
# 163726  253.667384  293.435173  264.800117  383.270738
# 152032  386.342251  466.091329  373.643375  399.977497
# 216752   95.606622   88.382667  133.420537   92.972211
# 23223    60.269439  112.398080   40.030258   80.787140
# 309410  111.824823   92.307202   88.328646   71.586149

# %%
pca.explained_variance_ratio_
# Out:
# array([0.96672895])

# %%
pca.components_
# Out:
# array([[0.33212089, 0.33241164, 0.3364763 , 0.33712652, 0.33664911,
#         0.32777328, 0.33344716, 0.3289958 , 0.3348648 ]])

# %%
outcomes_pca_df = pd.DataFrame(outcomes_pca)
outcomes_pca_df = outcomes_pca_df.rename(columns = {0: 'pca_outcome'})

# %%
outcomes_pca_df.sort_values('pca_outcome', ascending = False).head()
# Out:
#         pca_outcome
# 152032  1218.514219
# 163726   989.517136
# 216752   339.823294
# 309410   249.169757
# 401060   237.095760

# %%
biggest = outcomes_scaled_df.iloc[[152032], :]

# %%
biggest_multiplied = biggest * pca.components_

# %%
biggest_multiplied.sum(axis = 1)
# Out:
# 152032    1218.514219
# dtype: float64

# %% [markdown]
# Long story short: The input dataframe %*% pca.components_ = pca.transform().  In other words, if we want to know the value that pca transform will output for each observation in the data, we take the observed value of the predictors (which should have already been scaled) and multiply by the PCA components.

# %% [markdown]
# Lets take a look at the two big outliers to see what their other covariates look like

# %%
outliers = data.iloc[[152032, 163726], :]
outliers
# Out:
#                                              playlist_uri    owner  streams  \
# 152032  spotify:user:spotify:playlist:5FJXhjdILmRA2z5b...  spotify  2527075
# 163726  spotify:user:spotify:playlist:4hOKQuZbraPDIfaG...  spotify  2629715
#
#         stream30s     dau     wau      mau  mau_previous_month  \
# 152032    1461324  152929  669966  1944150             1478684
# 163726    1513237  122005  514627  1453097              970905
#
#         mau_both_months    users  skippers  n_tracks  n_local_tracks  \
# 152032           578391  3455406     86162        51               0
# 163726           364140  2448881     56707       100               0
#
#         n_artists  n_albums  monthly_stream30s  monthly_owner_stream30s  \
# 152032         51        51           42497334                       22
# 163726         93        86           40722305                        0
#
#                                            tokens genre_1        genre_2  \
# 152032                            ["top", "hits"]     Pop            R&B
# 163726  ["top", "tracks", "currently", "spotify"]     Pop  Dance & House
#
#               genre_3   mood_1   mood_2      mood_3
# 152032  Dance & House  Excited     Cool    Brooding
# 163726     Indie Rock  Excited  Defiant  Energizing

# %% [markdown]
# We see that the two really big outliers are both where owner = 'spotify'.  Let's see how many of the top rated according to the PCA analysis are where owner = 'spotify'

# %%
data_pca = outcomes_pca_df.join(data).sort_values('pca_outcome', ascending = False)
data_pca.head(30)
# Out:
#         pca_outcome                                       playlist_uri  \
# 152032  1218.514219  spotify:user:spotify:playlist:5FJXhjdILmRA2z5b...
# 163726   989.517136  spotify:user:spotify:playlist:4hOKQuZbraPDIfaG...
# 216752   339.823294  spotify:user:spotify:playlist:3ZgmfR6lsnCwdffZ...
# 309410   249.169757  spotify:user:spotify:playlist:5yolys8XG4q7YfjY...
# 401060   237.095760  spotify:user:spotify:playlist:3MlpudZs4HT3i0yG...
# 23223    236.289726  spotify:user:spotify:playlist:7jmQBEvJyGHPqKEl...
# 139600   215.894689  spotify:user:spotify:playlist:4BKT5olNFqLB1FAa...
# 228933   214.620716  spotify:user:spotify:playlist:16BpjqQV1Ey0HeDu...
# 141745   187.810251  spotify:user:spotify:playlist:1yHZ5C3penaxRdWR...
# 307283   177.908426  spotify:user:spotify:playlist:04MJzJlzOoy5bTyt...
# 401061   175.223357  spotify:user:spotify:playlist:4ecQaDJHF55Ls9m2...
# 313579   163.872058  spotify:user:spotify:playlist:103Zi2NG06F9qimA...
# 152033   162.876992  spotify:user:spotify:playlist:6uTuhSs7qiEPfCI3...
# 301290   158.738254  spotify:user:spotify:playlist:7EtGvEVYkL6knEdL...
# 210941   155.241165  spotify:user:spotify:playlist:2PXdUld4Ueio2pHc...
# 238664   149.913374  spotify:user:spotify:playlist:4dJHrPYVdKgaCE3L...
# 229719   143.253909  spotify:user:spotify:playlist:5Oo5QuAOjjXMMXph...
# 321521   140.997154  spotify:user:a19ebea5b5c28f3eff7f45167f7f3b1c:...
# 397553   138.961344  spotify:user:spotify:playlist:1GQLlzxBxKTb6tJs...
# 109390   138.043694  spotify:user:spotify:playlist:2ujjMpFriZ2nayLm...
# 401352   128.204913  spotify:user:spotify:playlist:5p9ILyu1wb4KKHOR...
# 208374   127.583310  spotify:user:spotify:playlist:76h0bH2KJhiBuLZq...
# 113001   122.457069  spotify:user:spotify:playlist:7uDoSz5VxK5lbXgj...
# 74899    118.806350  spotify:user:spotify:playlist:3qu74M0PqlkSV76f...
# 397753   114.776095  spotify:user:spotify:playlist:2jvJnYj1DfCT1tX0...
# 4646     112.318578  spotify:user:spotify:playlist:0i0KOEPUK7pA1A5A...
# 217378   109.981295  spotify:user:spotify:playlist:0ExbFrTy6ypLj9YY...
# 118387   106.719589  spotify:user:spotify:playlist:444MDFpUraOidJU5...
# 401724    96.649928  spotify:user:spotify:playlist:5tA2x3J6yAaJpa7m...
# 129324    95.627029  spotify:user:spotify:playlist:3jtuOxsrTRAWvPPL...
#
#                                    owner  streams  stream30s     dau     wau  \
# 152032                           spotify  2527075    1461324  152929  669966
# 163726                           spotify  2629715    1513237  122005  514627
# 216752                           spotify   735281     348391   43498  219817
# 309410                           spotify   579318     265613   28303  119724
# 401060                           spotify   505876     245377   33152  121173
# 23223                            spotify   678434     369994   33229  111094
# 139600                           spotify   353630     322268   19029  106822
# 228933                           spotify   439256     345999   24948  113779
# 141745                           spotify   137529      69313   10380  143516
# 307283                           spotify   252309     124903   16480   68518
# 401061                           spotify   280422     198981   17480   80832
# 313579                           spotify   306687     169082   19631   76700
# 152033                           spotify   232490     146048   13846   70322
# 301290                           spotify   274980     215027   15785   86217
# 210941                           spotify   325997     226854   18367   90866
# 238664                           spotify   200943     128842   15430   87757
# 229719                           spotify   216559     142918   19275   66811
# 321521  a19ebea5b5c28f3eff7f45167f7f3b1c   293283     173753   18290   71891
# 397553                           spotify   206610     111885   17727   79911
# 109390                           spotify   135929     115674   11212   86911
# 401352                           spotify   192830      95495   13254   81365
# 208374                           spotify   212248      98896   14582   81297
# 113001                           spotify   236234     131955   15707   56234
# 74899                            spotify   152867      79166   12829   74191
# 397753                           spotify   210551     130665   11129   58283
# 4646                             spotify   217215     171930   14768   63149
# 217378                           spotify   104862      87290    9360   76943
# 118387                           spotify   209535     120858   13322   62398
# 401724                           spotify   219996     139863   13720   73097
# 129324                           spotify   109304      61132    9051   55326
#
#             mau  mau_previous_month  mau_both_months    users  skippers  \
# 152032  1944150             1478684           578391  3455406     86162
# 163726  1453097              970905           364140  2448881     56707
# 216752   688999              365968           109688  1233952     34145
# 309410   339484              428039           114558   816966     15803
# 401060   430129              339921            79443   973788     23846
# 23223    241681              230724           139489   370328     14561
# 139600   307520              320197            84148   679714      7626
# 228933   326736              270341            66903   624553     11201
# 141745   352464              395305           101214   910599      7959
# 307283   278966              448102            75371   917174     11888
# 401061   222571              329108            88410   561010      6827
# 313579   266495              334421            51796   731904     13632
# 152033   262133              362881            68399   722658      7197
# 301290   251920              228454            59916   502913      6551
# 210941   252927              188028            48605   486127      9534
# 238664   285244              242113            67057   617340     12187
# 229719   226572              270507            50284   676617     17022
# 321521   206756              190026            59049   439699     11755
# 397553   230375              249319            57374   640684     16561
# 109390   265016              240448            50224   625116      6844
# 401352   235591              223459            52295   572246     10163
# 208374   271133              197929            42815   578081     13696
# 113001   204848              233325            37863   547574      9602
# 74899    258400              207825            44099   578269     13038
# 397753   181203              196280            42080   437889      7374
# 4646     189297              161926            24220   425719      7335
# 217378   231792              175464            39856   515379      5628
# 118387   190296              168663            29145   437494      9252
# 401724   203179               35745            15362   283754      7838
# 129324   196227              181446            42534   478982      9976
#
#         n_tracks  n_local_tracks  n_artists  n_albums  monthly_stream30s  \
# 152032        51               0         51        51           42497334
# 163726       100               0         93        86           40722305
# 216752       100               0        100        99            9879201
# 309410       402               0        189       159            7607014
# 401060        43               0         41        42            5567649
# 23223         50               0         47        45            8584584
# 139600       162               0         80        81           10536181
# 228933       106               0         99       103            8870847
# 141745        67               0         62        64            5230998
# 307283       296               0          1         1            4178965
# 401061        51               0         45        47            7101277
# 313579        81               0         77        77            3599989
# 152033       104               0         99       101            5290070
# 301290        68               0         59        66            6815852
# 210941        76               0         73        74            5701014
# 238664       100               0        100        99            4607037
# 229719       210               0          1         1            3404401
# 321521       522               0        448       501            5098585
# 397553        98               0         48        48            2955288
# 109390        91               0         54        83            5424456
# 401352       113               0        106       108            3249247
# 208374       100               0        100       100            2885107
# 113001        41               0         41        41            2571478
# 74899        100               0        100       100            2514937
# 397753        95               0         87        91            4232432
# 4646          65               0         60        63            3196805
# 217378       121               0          1         1            3668188
# 118387       104               0        102       101            2694381
# 401724       200               0        100       100            4202624
# 129324       100               0        100       100            2119701
#
#         monthly_owner_stream30s  \
# 152032                       22
# 163726                        0
# 216752                        0
# 309410                        3
# 401060                       44
# 23223                         5
# 139600                        3
# 228933                        3
# 141745                       34
# 307283                        8
# 401061                       10
# 313579                        0
# 152033                        3
# 301290                        1
# 210941                        7
# 238664                        0
# 229719                        6
# 321521                       40
# 397553                        2
# 109390                        6
# 401352                        1
# 208374                        1
# 113001                        0
# 74899                         0
# 397753                        2
# 4646                          7
# 217378                        0
# 118387                       11
# 401724                        1
# 129324                        0
#
#                                                    tokens         genre_1  \
# 152032                                    ["top", "hits"]             Pop
# 163726          ["top", "tracks", "currently", "spotify"]             Pop
# 216752                ["top", "pop", "tracks", "spotify"]             Pop
# 309410                         ["hip", "hop", "monsters"]             Rap
# 401060                                  ["teen", "party"]             Pop
# 23223                         ["top", "tracks", "sweden"]             Pop
# 139600                        ["favorite", "coffeehouse"]      Indie Rock
# 228933                          ["afternoon", "acoustic"]             Pop
# 141745                        ["new", "music", "tuesday"]      Indie Rock
# 307283                           ["dance", "mega", "mix"]   Dance & House
# 401061                            ["ultimate", "country"]  Country & Folk
# 313579                                ["summer", "party"]   Dance & House
# 152033                                ["mood", "booster"]             Pop
# 301290                            ["acoustic", "morning"]             Pop
# 210941                                          ["great"]             Pop
# 238664              ["top", "indie", "tracks", "spotify"]      Indie Rock
# 229719                            ["weekend", "hangouts"]   Dance & House
# 321521  ["edm", "updated", "daily", "house", "music", ...   Dance & House
# 397553                       ["fresh", "dance", "tracks"]   Dance & House
# 109390                                  ["deep", "focus"]      Indie Rock
# 401352                               ["power", "workout"]             Rap
# 208374                       ["top", "tracks", "spotify"]             R&B
# 113001                                          ["night"]             Pop
# 74899                ["top", "rock", "tracks", "spotify"]     Alternative
# 397753                                 ["pop", "ballads"]             Pop
# 4646                              ["hanging", "relaxing"]             Pop
# 217378                            ["intense", "studying"]       Classical
# 118387                                   ["wild", "free"]   Dance & House
# 401724            ["top", "country", "tracks", "spotify"]  Country & Folk
# 129324        ["top", "alternative", "tracks", "spotify"]     Alternative
#
#                genre_2         genre_3         mood_1         mood_2  \
# 152032             R&B   Dance & House        Excited           Cool
# 163726   Dance & House      Indie Rock        Excited        Defiant
# 216752             R&B             Rap        Excited        Defiant
# 309410             R&B             Pop        Defiant           Cool
# 401060             R&B             Rap        Excited       Yearning
# 23223    Dance & House      Indie Rock        Excited     Energizing
# 139600  Country & Folk             Pop     Melancholy      Easygoing
# 228933      Indie Rock  Country & Folk       Yearning       Romantic
# 141745     Alternative   Dance & House        Sensual       Yearning
# 307283     Electronica             Pop        Excited     Aggressive
# 401061  Spoken & Audio     Alternative         Upbeat       Yearning
# 313579             Rap             Pop        Excited        Defiant
# 152033      Indie Rock            Rock     Energizing        Excited
# 301290     Alternative      Indie Rock  Sophisticated    Sentimental
# 210941            Rock      Indie Rock          Rowdy        Excited
# 238664     Alternative            Rock       Yearning       Brooding
# 229719     Electronica             Pop        Excited        Sensual
# 321521     Electronica             Pop        Excited     Aggressive
# 397553     Electronica             Pop        Excited     Aggressive
# 109390     Electronica     Alternative     Melancholy       Yearning
# 401352           Metal     Electronica        Defiant           Cool
# 208374             Pop             Rap        Sensual        Defiant
# 113001             Rap             R&B        Excited     Energizing
# 74899             Punk      Indie Rock        Defiant         Urgent
# 397753             R&B      Indie Rock     Empowering  Sophisticated
# 4646        Indie Rock            Rock       Yearning        Excited
# 217378      Soundtrack           Other         Tender        Serious
# 118387             Pop      Indie Rock     Energizing        Excited
# 401724             Pop            Rock         Upbeat       Yearning
# 129324      Indie Rock            Rock        Defiant       Yearning
#
#                mood_3
# 152032       Brooding
# 163726     Energizing
# 216752     Empowering
# 309410     Energizing
# 401060         Urgent
# 23223         Defiant
# 139600         Gritty
# 228933         Gritty
# 141745        Excited
# 307283     Energizing
# 401061     Empowering
# 313579     Aggressive
# 152033       Yearning
# 301290       Yearning
# 210941     Energizing
# 238664        Defiant
# 229719     Energizing
# 321521     Energizing
# 397553     Energizing
# 109390       Romantic
# 401352     Energizing
# 208374  Sophisticated
# 113001        Defiant
# 74899        Yearning
# 397753       Yearning
# 4646       Empowering
# 217378       Romantic
# 118387       Yearning
# 401724     Empowering
# 129324     Empowering

# %%
my_corr = outcomes.corr().stack().reset_index(name = "correlation")
outcomes.head()
# Out:
#                                                     streams  stream30s  dau  \
# playlist_uri
# spotify:user:36069af6af076ccd9e597184a67b68c9:p...       27         27    1
# spotify:user:d1144a65b1c31c5f9f56b94f831124d5:p...        0          0    0
# spotify:user:6b7fbed9edd6418ddd3b555bba441536:p...        4          2    1
# spotify:user:580b98725077a94c3c8d01d07390426b:p...       12         12    1
# spotify:user:1305d39070c95d161cc502e15014897d:p...       20          4    1
#
#                                                     wau  mau  \
# playlist_uri
# spotify:user:36069af6af076ccd9e597184a67b68c9:p...    1    3
# spotify:user:d1144a65b1c31c5f9f56b94f831124d5:p...    1    2
# spotify:user:6b7fbed9edd6418ddd3b555bba441536:p...    1    7
# spotify:user:580b98725077a94c3c8d01d07390426b:p...    1    4
# spotify:user:1305d39070c95d161cc502e15014897d:p...    1    2
#
#                                                     mau_previous_month  \
# playlist_uri
# spotify:user:36069af6af076ccd9e597184a67b68c9:p...                   3
# spotify:user:d1144a65b1c31c5f9f56b94f831124d5:p...                   1
# spotify:user:6b7fbed9edd6418ddd3b555bba441536:p...                   5
# spotify:user:580b98725077a94c3c8d01d07390426b:p...                   6
# spotify:user:1305d39070c95d161cc502e15014897d:p...                   1
#
#                                                     mau_both_months  users  \
# playlist_uri
# spotify:user:36069af6af076ccd9e597184a67b68c9:p...                0      8
# spotify:user:d1144a65b1c31c5f9f56b94f831124d5:p...                1      3
# spotify:user:6b7fbed9edd6418ddd3b555bba441536:p...                0     15
# spotify:user:580b98725077a94c3c8d01d07390426b:p...                1     10
# spotify:user:1305d39070c95d161cc502e15014897d:p...                1      2
#
#                                                     monthly_stream30s
# playlist_uri
# spotify:user:36069af6af076ccd9e597184a67b68c9:p...                 30
# spotify:user:d1144a65b1c31c5f9f56b94f831124d5:p...                112
# spotify:user:6b7fbed9edd6418ddd3b555bba441536:p...                 63
# spotify:user:580b98725077a94c3c8d01d07390426b:p...                154
# spotify:user:1305d39070c95d161cc502e15014897d:p...                230

# %% [markdown]
# Taking a look here (for a small sample of the data) at the distribution of the various outcome variables against one another.

# %%
#sns.pairplot(outcomes.iloc[:100, :])

# %%
data_pca['spotify_owner'] = data_pca.owner == 'spotify'

# %%
test = (data_pca.
       groupby('spotify_owner').
       agg('mean').
       reset_index())

# %%
test2 = (data_pca.
        set_index('spotify_owner').
        reset_index())

# %%
test3 = test2.head(100)

# %% [markdown]
# 90 of the top 100 outcomes were when spotify was the owner.

# %%
test3.spotify_owner.mean()
# Out:
# 0.9

# %%
def prop_spotify(top_n):
    my_data = data_pca.head(top_n)
    return my_data.spotify_owner.mean()

# %%
x = list()
for n in range(1, 301):
    x.append(prop_spotify(n))

# %%
spotify_top = pd.DataFrame({'n': list(range(1, 301)),
                           'prop_spotify': x})

# %%
spotify_top.head(30)
# Out:
#      n  prop_spotify
# 0    1      1.000000
# 1    2      1.000000
# 2    3      1.000000
# 3    4      1.000000
# 4    5      1.000000
# 5    6      1.000000
# 6    7      1.000000
# 7    8      1.000000
# 8    9      1.000000
# 9   10      1.000000
# 10  11      1.000000
# 11  12      1.000000
# 12  13      1.000000
# 13  14      1.000000
# 14  15      1.000000
# 15  16      1.000000
# 16  17      1.000000
# 17  18      0.944444
# 18  19      0.947368
# 19  20      0.950000
# 20  21      0.952381
# 21  22      0.954545
# 22  23      0.956522
# 23  24      0.958333
# 24  25      0.960000
# 25  26      0.961538
# 26  27      0.962963
# 27  28      0.964286
# 28  29      0.965517
# 29  30      0.966667

# %%
spotify_top.plot.scatter(x = 'n', y = 'prop_spotify')
# Out:
# <AxesSubplot:xlabel='n', ylabel='prop_spotify'>

# %% [markdown]
# Let's now see if we can start fitting a model.  We will ultimately have to decide if we want to include spotify playlists in this presentation, but for now we will keep them in.

# %%
data_pca.columns
# Out:
# Index(['pca_outcome', 'playlist_uri', 'owner', 'streams', 'stream30s', 'dau',
#        'wau', 'mau', 'mau_previous_month', 'mau_both_months', 'users',
#        'skippers', 'n_tracks', 'n_local_tracks', 'n_artists', 'n_albums',
#        'monthly_stream30s', 'monthly_owner_stream30s', 'tokens', 'genre_1',
#        'genre_2', 'genre_3', 'mood_1', 'mood_2', 'mood_3', 'spotify_owner'],
#       dtype='object')

# %%
#from sklearn.preprocessing import LabelEncoder

y = data_pca.pca_outcome
X = data_pca.loc[:, ['spotify_owner', 
                     'n_tracks', 
                     'n_local_tracks', 
                     'n_artists', 
                     'n_albums', 
                     'genre_1', 
                     'genre_2',
                    'genre_3',
                     'mood_1',
                     'mood_2',
                     'mood_3'
                    ]]

#le = LabelEncoder()

X.genre_1 = X.genre_1.astype('category').cat.codes
X.genre_2 = X.genre_2.astype('category').cat.codes
X.genre_3 = X.genre_3.astype('category').cat.codes
X.mood_1 = X.mood_1.astype('category').cat.codes
X.mood_2 = X.mood_2.astype('category').cat.codes
X.mood_3 = X.mood_3.astype('category').cat.codes
X.info()

# X_test = X.genre_1.astype('category').cat_codes
# X_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 403366 entries, 152032 to 102682
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   spotify_owner   403366 non-null  bool
#  1   n_tracks        403366 non-null  int64
#  2   n_local_tracks  403366 non-null  int64
#  3   n_artists       403366 non-null  int64
#  4   n_albums        403366 non-null  int64
#  5   genre_1         403366 non-null  int8
#  6   genre_2         403366 non-null  int8
#  7   genre_3         403366 non-null  int8
#  8   mood_1          403366 non-null  int8
#  9   mood_2          403366 non-null  int8
#  10  mood_3          403366 non-null  int8
# dtypes: bool(1), int64(4), int8(6)
# memory usage: 18.1 MB

# %%
from sklearn.model_selection import KFold

kfold = KFold(n_splits = 10)

# %%
X_split = kfold.split(X)

# %%
import lightgbm as lgb

#params = {'learning_rate': 0.01}

lgb_mod = lgb.LGBMRegressor(learning_rate = 0.01,
                       n_estimators = 1000)

# %%
#lgb_mod.fit(X, y)

# %%
# print(lgb_mod.feature_name_)
# lgb_mod.feature_importances_

# %%
lgb_mod.fit(X, y, categorical_feature = ['genre_1', 'genre_2', 'genre_3', 'mood_1', 'mood_2', 'mood_3'])
# Out:
# C:\Users\Administrator\OneDrive\anaconda\lib\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# LGBMRegressor(learning_rate=0.01, n_estimators=1000)

# %%
print(lgb_mod.feature_name_)
lgb_mod.feature_importances_
# Out:
# ['spotify_owner', 'n_tracks', 'n_local_tracks', 'n_artists', 'n_albums', 'genre_1', 'genre_2', 'genre_3', 'mood_1', 'mood_2', 'mood_3']
# array([1036, 8192,  749, 7126, 6271,  984,  731,  826, 1065, 1439, 1581])

# %%
import shap 
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
explainer = shap.TreeExplainer(lgb_mod)
X_reduced = X.iloc[:2000, :]
shap_values = explainer.shap_values(X_reduced)

# %%
X_reduced_df = pd.DataFrame(X_reduced)
X_reduced_df.head()
# Out:
#         spotify_owner  n_tracks  n_local_tracks  n_artists  n_albums  genre_1  \
# 152032           True        51               0         51        51       16
# 163726           True       100               0         93        86       16
# 216752           True       100               0        100        99       16
# 309410           True       402               0        189       159       19
# 401060           True        43               0         41        42       16
#
#         genre_2  genre_3  mood_1  mood_2  mood_3
# 152032       18        6       8       3       2
# 163726        6       10       8       4       7
# 216752       18       19       8       4       6
# 309410       18       16       4       3       7
# 401060       18       19       8      26      25

# %%
shap.force_plot(explainer.expected_value, shap_values, X_reduced_df)
# Out:
# <div id='iX2RHVFGGOZ8KWC0BK6KV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": -7.328269516081672e-08, "link": "identity", "featureNames": ["spotify_owner", "n_tracks", "n_local_tracks", "n_artists", "n_albums", "genre_1", "genre_2", "genre_3", "mood_1", "mood_2", "mood_3"], "explanations": [{"outValue": 491.9238025311465, "simIndex": 1.0, "features": {"0": {"effect": 195.88695562398362, "value": true}, "1": {"effect": 43.20797362833174, "value": 51}, "2": {"effect": -0.00011620908151269808, "value": 0}, "3": {"effect": 62.78164973363841, "value": 51}, "4": {"effect": 36.88555932223649, "value": 51}, "5": {"effect": 13.93548287726828, "value": 16}, "6": {"effect": 16.129799985937094, "value": 18}, "7": {"effect": 18.113280776747427, "value": 6}, "8": {"effect": 41.2348011022493, "value": 8}, "9": {"effect": 41.78648652345664, "value": 3}, "10": {"effect": 21.961929239661764, "value": 2}}}, {"outValue": 434.3923728224316, "simIndex": 2.0, "features": {"0": {"effect": 186.63387583399356, "value": true}, "1": {"effect": 29.727777281533303, "value": 100}, "2": {"effect": 0.0007589247502200143, "value": 0}, "3": {"effect": 62.62206096666502, "value": 93}, "4": {"effect": 35.07876370783581, "value": 86}, "5": {"effect": 13.058408833733612, "value": 16}, "6": {"effect": 13.23986439975032, "value": 6}, "7": {"effect": 14.885762097843728, "value": 10}, "8": {"effect": 34.894456885453195, "value": 8}, "9": {"effect": 27.932681913585288, "value": 4}, "10": {"effect": 16.31796205057025, "value": 7}}}, {"outValue": 265.0592048878889, "simIndex": 3.0, "features": {"0": {"effect": 131.75553515300342, "value": true}, "1": {"effect": 26.04157741220725, "value": 100}, "2": {"effect": 0.0006990967281406446, "value": 0}, "3": {"effect": 40.73697664532732, "value": 100}, "4": {"effect": -7.98071683713351, "value": 99}, "5": {"effect": 10.852159525042422, "value": 16}, "6": {"effect": 9.133719080920695, "value": 18}, "7": {"effect": 14.35995230661794, "value": 19}, "8": {"effect": 23.41698051973914, "value": 8}, "9": {"effect": 13.385077488293529, "value": 4}, "10": {"effect": 3.3572445704252623, "value": 6}}}, {"outValue": 114.7197842929504, "simIndex": 11.0, "features": {"0": {"effect": 71.3695441231635, "value": true}, "1": {"effect": -0.0577125227655131, "value": 402}, "2": {"effect": 0.0442636271969473, "value": 0}, "3": {"effect": 15.024788133779925, "value": 189}, "4": {"effect": -6.7748781642872915, "value": 159}, "5": {"effect": 1.6330158932371093, "value": 19}, "6": {"effect": 7.006726422527801, "value": 18}, "7": {"effect": 0.10854627770558511, "value": 16}, "8": {"effect": 2.3581607952238444, "value": 4}, "9": {"effect": 21.67207172219675, "value": 3}, "10": {"effect": 2.3352580582544418, "value": 7}}}, {"outValue": 137.8383224493258, "simIndex": 26.0, "features": {"0": {"effect": 75.95631027266424, "value": true}, "1": {"effect": 18.062473984562217, "value": 43}, "2": {"effect": 0.0002770904601306168, "value": 0}, "3": {"effect": -5.224747061935824, "value": 41}, "4": {"effect": 6.16578507737811, "value": 42}, "5": {"effect": 7.8833118941854865, "value": 16}, "6": {"effect": 7.2255237992318015, "value": 18}, "7": {"effect": 7.654716903757885, "value": 19}, "8": {"effect": 16.725380248953137, "value": 8}, "9": {"effect": 3.3223751330074536, "value": 26}, "10": {"effect": 0.06691518034386064, "value": 25}}}, {"outValue": 136.5821206873632, "simIndex": 27.0, "features": {"0": {"effect": 74.61821957961676, "value": true}, "1": {"effect": 21.05664802571828, "value": 50}, "2": {"effect": 0.0002678225442567207, "value": 0}, "3": {"effect": -9.686175515927822, "value": 47}, "4": {"effect": 9.990602644292927, "value": 45}, "5": {"effect": 11.74048894712597, "value": 16}, "6": {"effect": 5.3901954311828275, "value": 6}, "7": {"effect": 7.706442248933506, "value": 10}, "8": {"effect": 19.142707897545368, "value": 8}, "9": {"effect": -2.548122011974369, "value": 7}, "10": {"effect": -0.8291543084118251, "value": 4}}}, {"outVal ...

# %%
shap.summary_plot(shap_values, X_reduced)

# %%
# ?shap.dependence_plot
# Out:
# Signature:
# shap.dependence_plot(
#     ind,
#     shap_values=None,
#     features=None,
#     feature_names=None,
#     display_features=None,
#     interaction_index='auto',
#     color='#1E88E5',
#     axis_color='#333333',
#     cmap=None,
#     dot_size=16,
#     x_jitter=0,
#     alpha=1,
#     title=None,
#     xmin=None,
#     xmax=None,
#     ax=None,
#     show=True,
# )
# Docstring:
# Create a SHAP dependence plot, colored by an interaction feature.
#
# Plots the value of the feature on the x-axis and the SHAP value of the same feature
# on the y-axis. This shows how the model depends on the given feature, and is like a
# richer extenstion of the classical parital dependence plots. Vertical dispersion of the
# data points represents interaction effects. Grey ticks along the y-axis are data
# points where the feature's value was NaN.
#
#
# Parameters
# ----------
# ind : int or string
#     If this is an int it is the index of the feature to plot. If this is a string it is
#     either the name of the feature to plot, or it can have the form "rank(int)" to specify
#     the feature with that rank (ordered by mean absolute SHAP value over all the samples).
#
# shap_values : numpy.array
#     Matrix of SHAP values (# samples x # features).
#
# features : numpy.array or pandas.DataFrame
#     Matrix of feature values (# samples x # features).
#
# feature_names : list
#     Names of the features (length # features).
#
# display_features : numpy.array or pandas.DataFrame
#     Matrix of feature values for visual display (such as strings instead of coded values).
#
# interaction_index : "auto", None, int, or string
#     The index of the feature used to color the plot. The name of a feature can also be passed
#     as a string. If "auto" then shap.common.approximate_interactions is used to pick what
#     seems to be the strongest interaction (note that to find to true stongest interaction you
#     need to compute the SHAP interaction values).
#
# x_jitter : float (0 - 1)
#     Adds random jitter to feature values. May increase plot readability when feature
#     is discrete.
#
# alpha : float
#     The transparency of the data points (between 0 and 1). This can be useful to the
#     show density of the data points when using a large dataset.
#
# xmin : float or string
#     Represents the lower bound of the plot's x-axis. It can be a string of the format
#     "percentile(float)" to denote that percentile of the feature's value used on the x-axis.
#
# xmax : float or string
#     Represents the upper bound of the plot's x-axis. It can be a string of the format
#     "percentile(float)" to denote that percentile of the feature's value used on the x-axis.
#
# ax : matplotlib Axes object
#      Optionally specify an existing matplotlib Axes object, into which the plot will be placed.
#      In this case we do not create a Figure, otherwise we do.
# File:      c:\users\administrator\onedrive\anaconda\lib\site-packages\shap\plots\_scatter.py
# Type:      function

# %%
for name in X_reduced.columns:
    shap.dependence_plot(name, shap_values, X_reduced)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
